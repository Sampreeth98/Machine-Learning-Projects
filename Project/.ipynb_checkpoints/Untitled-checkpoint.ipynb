# %% [markdown]
# #### I.Problem Description
# #### Predict if the Merchant is Fraudster or not for an e-commerce client
# #### ‘XYZ’ is a large e-commerce company with its operations in several countries. As the online giant grows, so has
# #### the number of fraudster merchants are. They deliver counterfeits or, in some cases, nothing at all. Such
# #### schemes leave customers duped, and place both legitimate merchants and the company itself in a constant
# #### battle to rid the marketplace of scammers. Determining this is also important in budgeting for fraud
# #### investigation. It's a well-known problem both to the company and to merchants, which they say hasn't
# #### effectively addressed the issue. They are serious about it and want to protect themselves from these fraudulent
# #### merchants using technology.
# #### You are expected to create an analytical and modelling framework to predict the Merchant Fraudulency(yes/no)
# #### based on the quantitative and qualitative features provided in the dataset while answering other questions too
# #### cited below.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import accuracy_score,recall_score,precision_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.naive_bayes import MultinomialNB 
from sklearn.naive_bayes import GaussianNB 
# %matplotlib inline

# %%
order= pd.read_csv("train_order_data-1561627847149.csv")
merc = pd.read_csv("train_merchant_data-1561627820784.csv")
Fr= pd.read_csv("train-1561627878332.csv")
ips = pd.read_csv("ip_boundaries_countries-1561628631121.csv")

# %%
order.head()
# Out:
#    Customer_ID      Order_ID        Date_of_Order  Order_Value_USD  \
# 0       126221  37cea9512f8d  2018-04-29 16:39:26              148
# 1       115471  09f12e6efde2  2018-06-16 17:05:40              145
# 2       151786  4e69e956e159  2018-10-26 18:00:46               62
# 3       140456  663443aaeb82  2018-12-12 05:41:52               28
# 4       114721  99258810c121  2018-09-20 11:06:10               70
#
#   Order_Source Order_Payment_Method  Merchant_ID
# 0       Direct          Credit Card       124231
# 1          SEO          Credit Card       136178
# 2          Ads     Internet Banking       198611
# 3          SEO           Debit Card       127993
# 4          Ads          Credit Card       250146

# %%
merc.head()
# Out:
#    Ecommerce_Provider_ID  Merchant_ID Merchant_Registration_Date  \
# 0                1746213        50448        2018-05-01 21:15:11
# 1                1746213       338754        2018-04-14 10:13:00
# 2                1746213       291127        2018-06-20 07:44:22
# 3                1746213       319919        2018-06-27 01:41:39
# 4                1746213       195911        2018-01-05 00:55:41
#
#   Registered_Device_ID Gender  Age      IP_Address
# 0        VATQMMZTVOZUT      F   39   48.151.136.76
# 1        LJCILLBRQZNKS      M   35    94.9.145.169
# 2        JFVHSUGKDAYZV      F   40   58.94.157.121
# 3        WFRXMPLQYXRMY      M   37  193.187.41.186
# 4        GGHKWMSWHCMID      F   27   125.96.20.172

# %%
merc = merc.drop(["Ecommerce_Provider_ID"],axis=1)

# %%
merc
# Out:
#        Merchant_ID Merchant_Registration_Date Registered_Device_ID Gender  \
# 0            50448        2018-05-01 21:15:11        VATQMMZTVOZUT      F
# 1           338754        2018-04-14 10:13:00        LJCILLBRQZNKS      M
# 2           291127        2018-06-20 07:44:22        JFVHSUGKDAYZV      F
# 3           319919        2018-06-27 01:41:39        WFRXMPLQYXRMY      M
# 4           195911        2018-01-05 00:55:41        GGHKWMSWHCMID      F
# ...            ...                        ...                  ...    ...
# 54208       222372        2018-05-01 21:58:19        KGVMENGCIAVOK      M
# 54209        73491        2018-06-11 19:54:13        QJGPOYDONTYCN      M
# 54210       176456        2018-01-06 20:05:55        ZOJNAJMGNRQPZ      F
# 54211       228277        2018-03-09 07:08:10        MQAOMNZFAHZLS      M
# 54212       259077        2018-04-04 04:15:34        AYPFCYPYQLLMO      F
#
#        Age      IP_Address
# 0       39   48.151.136.76
# 1       35    94.9.145.169
# 2       40   58.94.157.121
# 3       37  193.187.41.186
# 4       27   125.96.20.172
# ...    ...             ...
# 54208   43   247.25.244.31
# 54209   41   80.30.170.122
# 54210   36  188.39.154.217
# 54211   18  116.20.101.178
# 54212   31  171.47.212.179
#
# [54213 rows x 6 columns]

# %%
merco= merc.sort_values('Merchant_ID')
ordero= order.sort_values('Merchant_ID')

# %%
merco
# Out:
#        Ecommerce_Provider_ID  Merchant_ID Merchant_Registration_Date  \
# 18128                1746213            2        2018-01-11 03:47:13
# 14616                1746213            4        2018-06-02 16:40:57
# 36242                1746213           33        2018-08-10 08:30:49
# 42407                1746213           41        2018-01-30 06:43:52
# 2761                 1746213           44        2018-03-11 13:44:43
# ...                      ...          ...                        ...
# 13468                1746213       399965        2018-06-08 16:22:24
# 6623                 1746213       399971        2018-07-22 00:49:24
# 13045                1746213       399987        2018-01-20 09:56:11
# 12442                1746213       399992        2018-06-04 17:43:28
# 49077                1746213       399993        2018-07-30 03:41:08
#
#       Registered_Device_ID Gender  Age      IP_Address
# 18128        STODAQAORGSWW      F   25   52.119.13.140
# 14616        ZXSHVIBUYWOLA      F   38  166.13.141.186
# 36242        IIDYBZOGBJIQQ      F   32   71.170.11.189
# 42407        ZJQEGUIMFEAJE      F   28   98.86.110.205
# 2761         LLZDZZVFWCUKS      F   33  245.89.131.248
# ...                    ...    ...  ...             ...
# 13468        ZPKITRCOIEEJS      M   35    11.84.35.251
# 6623         LRNPVSYLPDBTP      F   26  226.126.25.209
# 13045        UMAZHOTAPDHTI      M   28   170.66.123.50
# 12442        PAISRQFPNJKTF      M   59      92.91.6.98
# 49077        KWZGONXBUXGTE      F   37    164.59.32.95
#
# [54213 rows x 7 columns]

# %%
ordero
# Out:
#        Customer_ID      Order_ID        Date_of_Order  Order_Value_USD  \
# 5980        141033  328aca82a1ed  2018-02-23 10:03:37              135
# 31195       117580  a08573d3abed  2018-09-28 21:32:16              102
# 24455       138528  76fad3f4d254  2018-10-30 18:12:41              128
# 44967       136111  fa608bf56f15  2018-03-25 10:10:08              138
# 32058       141646  8e767b8adde6  2018-06-28 05:45:06               82
# ...            ...           ...                  ...              ...
# 15466       120278  14325d170e0f  2018-07-21 06:31:13               52
# 12561       138941  0c58c83c90ca  2018-08-17 10:22:06               95
# 9980        131127  2fb8af4e158d  2018-04-28 09:55:20               75
# 5865        128893  49e932ffeff6  2018-10-02 07:19:17              205
# 23962       139192  2adae754e9a3  2018-10-03 07:16:25               50
#
#       Order_Source Order_Payment_Method  Merchant_ID
# 5980           SEO          Credit Card            2
# 31195       Direct           Debit Card            4
# 24455       Direct          Credit Card           33
# 44967          Ads     Internet Banking           41
# 32058       Direct          Credit Card           44
# ...            ...                  ...          ...
# 15466          Ads     Internet Banking       399965
# 12561          SEO           Debit Card       399971
# 9980        Direct     Internet Banking       399987
# 5865        Direct           Debit Card       399992
# 23962       Direct     Internet Banking       399993
#
# [54213 rows x 7 columns]

# %%
ordero.columns
# Out:
# Index(['Customer_ID', 'Order_ID', 'Date_of_Order', 'Order_Value_USD',
#        'Order_Source', 'Order_Payment_Method', 'Merchant_ID'],
#       dtype='object')

# %%
dfinal = merc.merge((order), on="Merchant_ID", how = 'inner')

# %%
dfinal

# %%
ofinal= merco.merge(ordero, on="Merchant_ID", how = 'inner')

# %%
ofinal= ofinal.merge(Fr, on = "Merchant_ID", how = 'inner')

# %%
ofinal
# Out:
#        Ecommerce_Provider_ID  Merchant_ID Merchant_Registration_Date  \
# 0                    1746213            2        2018-01-11 03:47:13
# 1                    1746213            4        2018-06-02 16:40:57
# 2                    1746213           33        2018-08-10 08:30:49
# 3                    1746213           41        2018-01-30 06:43:52
# 4                    1746213           44        2018-03-11 13:44:43
# ...                      ...          ...                        ...
# 54208                1746213       399965        2018-06-08 16:22:24
# 54209                1746213       399971        2018-07-22 00:49:24
# 54210                1746213       399987        2018-01-20 09:56:11
# 54211                1746213       399992        2018-06-04 17:43:28
# 54212                1746213       399993        2018-07-30 03:41:08
#
#       Registered_Device_ID Gender  Age      IP_Address  Customer_ID  \
# 0            STODAQAORGSWW      F   25   52.119.13.140       141033
# 1            ZXSHVIBUYWOLA      F   38  166.13.141.186       117580
# 2            IIDYBZOGBJIQQ      F   32   71.170.11.189       138528
# 3            ZJQEGUIMFEAJE      F   28   98.86.110.205       136111
# 4            LLZDZZVFWCUKS      F   33  245.89.131.248       141646
# ...                    ...    ...  ...             ...          ...
# 54208        ZPKITRCOIEEJS      M   35    11.84.35.251       120278
# 54209        LRNPVSYLPDBTP      F   26  226.126.25.209       138941
# 54210        UMAZHOTAPDHTI      M   28   170.66.123.50       131127
# 54211        PAISRQFPNJKTF      M   59      92.91.6.98       128893
# 54212        KWZGONXBUXGTE      F   37    164.59.32.95       139192
#
#            Order_ID        Date_of_Order  Order_Value_USD Order_Source  \
# 0      328aca82a1ed  2018-02-23 10:03:37              135          SEO
# 1      a08573d3abed  2018-09-28 21:32:16              102       Direct
# 2      76fad3f4d254  2018-10-30 18:12:41              128       Direct
# 3      fa608bf56f15  2018-03-25 10:10:08              138          Ads
# 4      8e767b8adde6  2018-06-28 05:45:06               82       Direct
# ...             ...                  ...              ...          ...
# 54208  14325d170e0f  2018-07-21 06:31:13               52          Ads
# 54209  0c58c83c90ca  2018-08-17 10:22:06               95          SEO
# 54210  2fb8af4e158d  2018-04-28 09:55:20               75       Direct
# 54211  49e932ffeff6  2018-10-02 07:19:17              205       Direct
# 54212  2adae754e9a3  2018-10-03 07:16:25               50       Direct
#
#       Order_Payment_Method  Fraudster
# 0              Credit Card          0
# 1               Debit Card          0
# 2              Credit Card          0
# 3         Internet Banking          0
# 4              Credit Card          1
# ...                    ...        ...
# 54208     Internet Banking          0
# 54209           Debit Card          0
# 54210     Internet Banking          0
# 54211           Debit Card          0
# 54212     Internet Banking          0
#
# [54213 rows x 14 columns]

# %%
ofinal = ofinal.drop(['Registered_Device_ID','Ecommerce_Provider_ID','Customer_ID','Order_ID','Date_of_Order','Merchant_Registration_Date'],axis=1)

# %%
ofinal.head()
# Out:
#    Merchant_ID Gender  Age      IP_Address  Order_Value_USD Order_Source  \
# 0            2      F   25   52.119.13.140              135          SEO
# 1            4      F   38  166.13.141.186              102       Direct
# 2           33      F   32   71.170.11.189              128       Direct
# 3           41      F   28   98.86.110.205              138          Ads
# 4           44      F   33  245.89.131.248               82       Direct
#
#   Order_Payment_Method  Fraudster
# 0          Credit Card          0
# 1           Debit Card          0
# 2          Credit Card          0
# 3     Internet Banking          0
# 4          Credit Card          1

# %%
ofinal.describe()
# Out:
#          Merchant_ID           Age  Order_Value_USD    Fraudster
# count   54213.000000  54213.000000     54213.000000  54213.00000
# mean   200395.176212     33.122240        92.230240      0.09269
# std    115398.486895      8.630091        45.673263      0.29000
# min         2.000000     18.000000        22.000000      0.00000
# 25%    100997.000000     27.000000        55.000000      0.00000
# 50%    200574.000000     32.000000        88.000000      0.00000
# 75%    300407.000000     39.000000       122.000000      0.00000
# max    399993.000000     72.000000       385.000000      1.00000

# %%
ofinal.dtypes
# Out:
# Merchant_ID              int64
# Gender                  object
# Age                      int64
# IP_Address              object
# Order_Value_USD          int64
# Order_Source            object
# Order_Payment_Method    object
# Fraudster                int64
# dtype: object

# %%
##### Gender Order_Source Order_Payment_Method are categorical variables hence converting

# %%
#!pip install maxminddb-geolite2
from geolite2 import geolite2
geo = geolite2.reader()
def getcon(ip):
    try:
        x = geo.get(ip)
    except ValueError:
        return 'Other'
    try:
        return x['country']['names']['en'] if x else 'Other'
    except KeyError:
        return 'Other'

# %%
import ipaddress
x= getcon('52.119.13.140')
x
# Out:
# 'United States'

# %%
# def ipadds(ip):
#     for values in ips:
#         if ipaddress.ip_address(ip)>=ipaddress.ip_address(ips['lower_bound_ip_address']) & ipaddress.ip_address(ip)<=ipaddress.ip_address(ips['upper_bound_ip_address']):
#             return ips.at[values,'country']
#             break
        
    
ofi = ofinal
#ofi['IP_Address'] = ofi['IP_Address'].astype('|S')
#ofi['IP_Address']= ofi['IP_Address'].apply(ipadds)
#ips['lower_bound_ip_address']= ips['lower_bound_ip_address'].apply(ipadds)

# %%
ofinal['Country']= ofinal['IP_Address'].apply(getcon)

# %%
ofinal
# Out:
#        Merchant_ID Gender  Age      IP_Address  Order_Value_USD Order_Source  \
# 0                2      F   25   52.119.13.140              135          SEO
# 1                4      F   38  166.13.141.186              102       Direct
# 2               33      F   32   71.170.11.189              128       Direct
# 3               41      F   28   98.86.110.205              138          Ads
# 4               44      F   33  245.89.131.248               82       Direct
# ...            ...    ...  ...             ...              ...          ...
# 54208       399965      M   35    11.84.35.251               52          Ads
# 54209       399971      F   26  226.126.25.209               95          SEO
# 54210       399987      M   28   170.66.123.50               75       Direct
# 54211       399992      M   59      92.91.6.98              205       Direct
# 54212       399993      F   37    164.59.32.95               50       Direct
#
#       Order_Payment_Method  Fraudster        Country
# 0              Credit Card          0  United States
# 1               Debit Card          0    Switzerland
# 2              Credit Card          0  United States
# 3         Internet Banking          0  United States
# 4              Credit Card          1          Other
# ...                    ...        ...            ...
# 54208     Internet Banking          0  United States
# 54209           Debit Card          0          Other
# 54210     Internet Banking          0         Brazil
# 54211           Debit Card          0         France
# 54212     Internet Banking          0        Germany
#
# [54213 rows x 9 columns]

# %%
ofinal = ofinal.drop(['IP_Address'],axis=1)
ofinal
# Out:
#        Merchant_ID Gender  Age  Order_Value_USD Order_Source  \
# 0                2      F   25              135          SEO
# 1                4      F   38              102       Direct
# 2               33      F   32              128       Direct
# 3               41      F   28              138          Ads
# 4               44      F   33               82       Direct
# ...            ...    ...  ...              ...          ...
# 54208       399965      M   35               52          Ads
# 54209       399971      F   26               95          SEO
# 54210       399987      M   28               75       Direct
# 54211       399992      M   59              205       Direct
# 54212       399993      F   37               50       Direct
#
#       Order_Payment_Method  Fraudster        Country
# 0              Credit Card          0  United States
# 1               Debit Card          0    Switzerland
# 2              Credit Card          0  United States
# 3         Internet Banking          0  United States
# 4              Credit Card          1          Other
# ...                    ...        ...            ...
# 54208     Internet Banking          0  United States
# 54209           Debit Card          0          Other
# 54210     Internet Banking          0         Brazil
# 54211           Debit Card          0         France
# 54212     Internet Banking          0        Germany
#
# [54213 rows x 8 columns]

# %%
ofc = ofinal
cat_attr=['Gender','Order_Source','Order_Payment_Method', 'Fraudster']
for col in cat_attr:
     ofc[col] = ofinal[col].astype('category')
ofc
# Out:
#        Merchant_ID Gender  Age  Order_Value_USD Order_Source  \
# 0                2      F   25              135          SEO
# 1                4      F   38              102       Direct
# 2               33      F   32              128       Direct
# 3               41      F   28              138          Ads
# 4               44      F   33               82       Direct
# ...            ...    ...  ...              ...          ...
# 54208       399965      M   35               52          Ads
# 54209       399971      F   26               95          SEO
# 54210       399987      M   28               75       Direct
# 54211       399992      M   59              205       Direct
# 54212       399993      F   37               50       Direct
#
#       Order_Payment_Method Fraudster
# 0              Credit Card         0
# 1               Debit Card         0
# 2              Credit Card         0
# 3         Internet Banking         0
# 4              Credit Card         1
# ...                    ...       ...
# 54208     Internet Banking         0
# 54209           Debit Card         0
# 54210     Internet Banking         0
# 54211           Debit Card         0
# 54212     Internet Banking         0
#
# [54213 rows x 7 columns]

# %%
ofc.dtypes
# Out:
# Merchant_ID                int64
# Gender                  category
# Age                        int64
# Order_Value_USD            int64
# Order_Source            category
# Order_Payment_Method    category
# Fraudster               category
# Country                 category
# dtype: object

# %%
import plotly.express as plt

# %%
Age,Order_Value_USD

# %%
data = pd.get_dummies( ofc, prefix=cat_attr, prefix_sep="_", drop_first=True)
data.head()
# Out:
#    Merchant_ID  Age  Order_Value_USD  Gender_M  Order_Source_Direct  \
# 0            2   25              135         0                    0
# 1            4   38              102         0                    1
# 2           33   32              128         0                    1
# 3           41   28              138         0                    0
# 4           44   33               82         0                    1
#
#    Order_Source_SEO  Order_Payment_Method_Credit Card  \
# 0                 1                                 1
# 1                 0                                 0
# 2                 0                                 1
# 3                 0                                 0
# 4                 0                                 1
#
#    Order_Payment_Method_Debit Card  Order_Payment_Method_E-wallet  \
# 0                                0                              0
# 1                                1                              0
# 2                                0                              0
# 3                                0                              0
# 4                                0                              0
#
#    Order_Payment_Method_Internet Banking  ...  Country_Uganda  \
# 0                                      0  ...               0
# 1                                      0  ...               0
# 2                                      0  ...               0
# 3                                      1  ...               0
# 4                                      0  ...               0
#
#    Country_Ukraine  Country_United Arab Emirates  Country_United Kingdom  \
# 0                0                             0                       0
# 1                0                             0                       0
# 2                0                             0                       0
# 3                0                             0                       0
# 4                0                             0                       0
#
#    Country_United States  Country_Uruguay  Country_Uzbekistan  \
# 0                      1                0                   0
# 1                      0                0                   0
# 2                      1                0                   0
# 3                      1                0                   0
# 4                      0                0                   0
#
#    Country_Venezuela  Country_Vietnam  Country_Zambia
# 0                  0                0               0
# 1                  0                0               0
# 2                  0                0               0
# 3                  0                0               0
# 4                  0                0               0
#
# [5 rows x 138 columns]

# %%
ofc = ofc.drop(['Country'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2276\2067420409.py in <module>
# ----> 1 ofc = ofc.drop(['Country'],axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['Country'] not found in axis"

# %%
data = pd.get_dummies( ofc, prefix=cat_attr, prefix_sep="_", drop_first=True)
data
# Out:
#        Merchant_ID  Age  Order_Value_USD  Gender_M  Order_Source_Direct  \
# 0                2   25              135         0                    0
# 1                4   38              102         0                    1
# 2               33   32              128         0                    1
# 3               41   28              138         0                    0
# 4               44   33               82         0                    1
# ...            ...  ...              ...       ...                  ...
# 54208       399965   35               52         1                    0
# 54209       399971   26               95         0                    0
# 54210       399987   28               75         1                    1
# 54211       399992   59              205         1                    1
# 54212       399993   37               50         0                    1
#
#        Order_Source_SEO  Order_Payment_Method_Credit Card  \
# 0                     1                                 1
# 1                     0                                 0
# 2                     0                                 1
# 3                     0                                 0
# 4                     0                                 1
# ...                 ...                               ...
# 54208                 0                                 0
# 54209                 1                                 0
# 54210                 0                                 0
# 54211                 0                                 0
# 54212                 0                                 0
#
#        Order_Payment_Method_Debit Card  Order_Payment_Method_E-wallet  \
# 0                                    0                              0
# 1                                    1                              0
# 2                                    0                              0
# 3                                    0                              0
# 4                                    0                              0
# ...                                ...                            ...
# 54208                                0                              0
# 54209                                1                              0
# 54210                                0                              0
# 54211                                1                              0
# 54212                                0                              0
#
#        Order_Payment_Method_Internet Banking  Fraudster_1
# 0                                          0            0
# 1                                          0            0
# 2                                          0            0
# 3                                          1            0
# 4                                          0            1
# ...                                      ...          ...
# 54208                                      1            0
# 54209                                      0            0
# 54210                                      1            0
# 54211                                      0            0
# 54212                                      1            0
#
# [54213 rows x 11 columns]

# %%
X = data.loc[:,data.columns.difference(['Fraudster_1','Merchant_ID'])]
y = data.Fraudster_1

# %%
X
# Out:
#        Age  Gender_M  Order_Payment_Method_Credit Card  \
# 0       25         0                                 1
# 1       38         0                                 0
# 2       32         0                                 1
# 3       28         0                                 0
# 4       33         0                                 1
# ...    ...       ...                               ...
# 54208   35         1                                 0
# 54209   26         0                                 0
# 54210   28         1                                 0
# 54211   59         1                                 0
# 54212   37         0                                 0
#
#        Order_Payment_Method_Debit Card  Order_Payment_Method_E-wallet  \
# 0                                    0                              0
# 1                                    1                              0
# 2                                    0                              0
# 3                                    0                              0
# 4                                    0                              0
# ...                                ...                            ...
# 54208                                0                              0
# 54209                                1                              0
# 54210                                0                              0
# 54211                                1                              0
# 54212                                0                              0
#
#        Order_Payment_Method_Internet Banking  Order_Source_Direct  \
# 0                                          0                    0
# 1                                          0                    1
# 2                                          0                    1
# 3                                          1                    0
# 4                                          0                    1
# ...                                      ...                  ...
# 54208                                      1                    0
# 54209                                      0                    0
# 54210                                      1                    1
# 54211                                      0                    1
# 54212                                      1                    1
#
#        Order_Source_SEO  Order_Value_USD
# 0                     1              135
# 1                     0              102
# 2                     0              128
# 3                     0              138
# 4                     0               82
# ...                 ...              ...
# 54208                 0               52
# 54209                 1               95
# 54210                 0               75
# 54211                 0              205
# 54212                 0               50
#
# [54213 rows x 9 columns]

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 54208    0
# 54209    0
# 54210    0
# 54211    0
# 54212    0
# Name: Fraudster_1, Length: 54213, dtype: uint8

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify= y, test_size = 0.3, random_state=183)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (37949, 9)
# (16264, 9)
# (37949,)
# (16264,)

# %%
scaler = MinMaxScaler()                                     #standardize numerical variables
X_train[['Age','Order_Value_USD']] = scaler.fit_transform(X_train[['Age','Order_Value_USD']])
X_test[['Age','Order_Value_USD']]=scaler.transform(X_test[['Age','Order_Value_USD']])

# %%
import statsmodels.api as sm
X_train = sm.add_constant(X_train)
X_test = sm.add_constant(X_test)

# %% [markdown]
# #### Model Building

# %%
logit_model=sm.Logit(y_train,X_train)
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 529.400907
#          Iterations 6
#                                     Results: Logit
# ======================================================================================
# Model:                    Logit                  Pseudo R-squared:       inf
# Dependent Variable:       Fraudster_1            AIC:                    40180490.0763
# Date:                     2023-02-12 14:14       BIC:                    40180575.5162
# No. Observations:         37949                  Log-Likelihood:         -2.0090e+07
# Df Model:                 9                      LL-Null:                0.0000
# Df Residuals:             37939                  LLR p-value:            1.0000
# Converged:                1.0000                 Scale:                  1.0000
# No. Iterations:           6.0000
# --------------------------------------------------------------------------------------
#                                        Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# --------------------------------------------------------------------------------------
# const                                 -2.4871   0.1267 -19.6242 0.0000 -2.7355 -2.2387
# Age                                    0.2586   0.1043   2.4795 0.0132  0.0542  0.4630
# Gender_M                               0.0723   0.0362   1.9976 0.0458  0.0014  0.1432
# Order_Payment_Method_Credit Card       0.1821   0.1192   1.5277 0.1266 -0.0515  0.4157
# Order_Payment_Method_Debit Card        0.1097   0.1239   0.8850 0.3762 -0.1332  0.3525
# Order_Payment_Method_E-wallet          0.1389   0.1241   1.1187 0.2633 -0.1044  0.3822
# Order_Payment_Method_Internet Banking  0.0533   0.1218   0.4376 0.6617 -0.1854  0.2919
# Order_Source_Direct                    0.0842   0.0468   1.7994 0.0719 -0.0075  0.1759
# Order_Source_SEO                      -0.1036   0.0402  -2.5750 0.0100 -0.1824 -0.0247
# Order_Value_USD                       -0.0882   0.1167  -0.7558 0.4498 -0.3169  0.1405
# ======================================================================================
# C:\Users\samje\anaconda3\lib\site-packages\statsmodels\base\model.py:592: HessianInversionWarning:
#
# Inverting hessian failed, no bse or cov_params available
#
# C:\Users\samje\anaconda3\lib\site-packages\statsmodels\base\model.py:592: HessianInversionWarning:
#
# Inverting hessian failed, no bse or cov_params available
#
# C:\Users\samje\anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:3511: RuntimeWarning:
#
# divide by zero encountered in double_scalars
